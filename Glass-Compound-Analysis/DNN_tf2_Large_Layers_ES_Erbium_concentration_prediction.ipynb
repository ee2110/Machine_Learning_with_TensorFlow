# %% [markdown]
# **Attention**
#
# This notebook is for experiment purpose. Since the actual output of the erbium concentration is descrete value, range from 0.01 to 0.05, and the variation between them is very small causing difficulty in accurate prediction. Therefore, this notebook is to shows the problem on the prediction and we will work on another notebook to treat it as classification task.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import time

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing
from keras.callbacks import EarlyStopping

# %%
# !ls
# Out:
# sample_data  Structured_features.csv

# %%
data = pd.read_csv('Structured_features.csv')
data
# Out:
#      Longitudinal modulus  ...  Erbium Concentration
# 0               60.505571  ...                  0.01
# 1               61.749309  ...                  0.01
# 2               60.206152  ...                  0.01
# 3               62.014179  ...                  0.01
# 4               62.831822  ...                  0.01
# ..                    ...  ...                   ...
# 245             58.273308  ...                  0.05
# 246             57.141365  ...                  0.05
# 247             61.777979  ...                  0.05
# 248             58.251540  ...                  0.05
# 249             60.341281  ...                  0.05
#
# [250 rows x 8 columns]

# %%
train_dataset = data.sample(frac=0.8, random_state=0)
test_dataset = data.drop(train_dataset.index)

# %%
train_dataset[:10]
# Out:
#      Longitudinal modulus  ...  Erbium Concentration
# 225             66.425882  ...                  0.05
# 122             63.501343  ...                  0.03
# 92              59.015531  ...                  0.02
# 157             63.281998  ...                  0.04
# 154             75.022997  ...                  0.04
# 161             59.679243  ...                  0.04
# 198             56.367327  ...                  0.04
# 83              53.400675  ...                  0.02
# 63              53.422477  ...                  0.02
# 155             61.760233  ...                  0.04
#
# [10 rows x 8 columns]

# %%
data.isna().sum()
# Out:
# Longitudinal modulus         0
# Shear modulus                0
# Bulk modulus                 0
# Young modulus                0
# Poisson's ratio              0
# Hardness                     0
# fractal bond connectivity    0
# Erbium Concentration         0
# dtype: int64

# %%
col_name = list(data.columns)
col_name
# Out:
# ['Longitudinal modulus',
#  'Shear modulus',
#  'Bulk modulus',
#  'Young modulus',
#  "Poisson's ratio",
#  'Hardness',
#  'fractal bond connectivity',
#  'Erbium Concentration']

# %%
train_col_name = list(data.columns[:-1])
train_col_name
# Out:
# ['Longitudinal modulus',
#  'Shear modulus',
#  'Bulk modulus',
#  'Young modulus',
#  "Poisson's ratio",
#  'Hardness',
#  'fractal bond connectivity']

# %%
sns.pairplot(train_dataset[col_name], diag_kind='kde')

# %%
train_dataset.describe().transpose()
# Out:
#                            count       mean  ...        75%        max
# Longitudinal modulus       200.0  61.954316  ...  64.036460  76.161742
# Shear modulus              200.0  20.138510  ...  20.691405  24.432039
# Bulk modulus               200.0  35.030650  ...  37.297866  44.089459
# Young modulus              200.0  50.644562  ...  52.068897  61.217865
# Poisson's ratio            200.0   0.258144  ...   0.269240   0.287009
# Hardness                   200.0   3.247638  ...   3.435733   4.333593
# fractal bond connectivity  200.0   2.316184  ...   2.462993   3.417749
# Erbium Concentration       200.0   0.029600  ...   0.040000   0.050000
#
# [8 rows x 8 columns]

# %%
# Collect input feature for training, molar volume value in this case
train_features = train_dataset.copy() #dataframe type
test_features = test_dataset.copy()

# Collect respective label, density value in this case
train_labels = train_features.pop('Erbium Concentration') # series type
test_labels = test_features.pop('Erbium Concentration')

# %%
normalizer = preprocessing.Normalization()
normalizer.adapt(np.array(train_features))
print(normalizer.mean.numpy())
# Out:
# [61.954315  20.13851   35.03065   50.64456    0.2581441  3.247638
#   2.3161843]

# %%
input_feature = np.array(train_features[train_col_name])

input_feature_normalizer = preprocessing.Normalization(input_shape=[1,])
input_feature_normalizer.adapt(input_feature)

# %%
basic_model = keras.Sequential([
    input_feature_normalizer,
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(1)
])

basic_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalization_1 (Normalizati (None, 7)                 15
# _________________________________________________________________
# dense (Dense)                (None, 64)                512
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 58,384
# Trainable params: 58,369
# Non-trainable params: 15
# _________________________________________________________________

# %%
basic_model.compile(
    optimizer=tf.optimizers.Adam(learning_rate=0.0001),
    loss='mean_absolute_error')

# %%
train_features
# Out:
#      Longitudinal modulus  Shear modulus  ...  Hardness  fractal bond connectivity
# 225             66.425882      19.892242  ...  2.834518                   1.994065
# 122             63.501343      18.969675  ...  2.693578                   1.985915
# 92              59.015531      20.495892  ...  3.635216                   2.587238
# 157             63.281998      20.478164  ...  3.265714                   2.276757
# 154             75.022997      24.277571  ...  3.871616                   2.276757
# ..                    ...            ...  ...       ...                        ...
# 183             60.422223      19.767204  ...  3.203724                   2.321051
# 114             63.459155      20.283022  ...  3.176145                   2.227978
# 163             62.626366      19.779326  ...  3.043553                   2.182310
# 151             58.786939      19.023555  ...  3.033743                   2.276757
# 31              61.300340      20.471326  ...  3.421384                   2.408020
#
# [200 rows x 7 columns]

# %%
input_train = train_features[train_col_name]
input_train
# Out:
#      Longitudinal modulus  Shear modulus  ...  Hardness  fractal bond connectivity
# 225             66.425882      19.892242  ...  2.834518                   1.994065
# 122             63.501343      18.969675  ...  2.693578                   1.985915
# 92              59.015531      20.495892  ...  3.635216                   2.587238
# 157             63.281998      20.478164  ...  3.265714                   2.276757
# 154             75.022997      24.277571  ...  3.871616                   2.276757
# ..                    ...            ...  ...       ...                        ...
# 183             60.422223      19.767204  ...  3.203724                   2.321051
# 114             63.459155      20.283022  ...  3.176145                   2.227978
# 163             62.626366      19.779326  ...  3.043553                   2.182310
# 151             58.786939      19.023555  ...  3.033743                   2.276757
# 31              61.300340      20.471326  ...  3.421384                   2.408020
#
# [200 rows x 7 columns]

# %%
# patient early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=100)

history = basic_model.fit(
    input_train, train_labels,
    epochs=1000,
    verbose=1,
    # Calculate validation results on 20% of the training data
    validation_split = 0.2,
    callbacks=[es])
# Out:
# Epoch 1/1000
# WARNING:tensorflow:Model was constructed with shape (None, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name='normalization_1_input'), name='normalization_1_input', description="created by layer 'normalization_1_input'"), but it was called on an input with incompatible shape (32, 7).
# WARNING:tensorflow:Model was constructed with shape (None, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name='normalization_1_input'), name='normalization_1_input', description="created by layer 'normalization_1_input'"), but it was called on an input with incompatible shape (32, 7).
# 1/5 [=====>........................] - ETA: 2s - loss: 0.0832WARNING:tensorflow:Model was constructed with shape (None, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name='normalization_1_input'), name='normalization_1_input', description="created by layer 'normalization_1_input'"), but it was called on an input with incompatible shape (None, 7).
# 5/5 [==============================] - 1s 100ms/step - loss: 0.0846 - val_loss: 0.0318
# Epoch 2/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0702 - val_loss: 0.0282
# Epoch 3/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0890 - val_loss: 0.0249
# Epoch 4/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0700 - val_loss: 0.0217
# Epoch 5/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0647 - val_loss: 0.0195
# Epoch 6/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0819 - val_loss: 0.0170
# Epoch 7/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0715 - val_loss: 0.0157
# Epoch 8/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0582 - val_loss: 0.0142
# Epoch 9/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0624 - val_loss: 0.0138
# Epoch 10/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0596 - val_loss: 0.0141
# Epoch 11/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0585 - val_loss: 0.0142
# Epoch 12/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0613 - val_loss: 0.0147
# Epoch 13/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0708 - val_loss: 0.0156
# Epoch 14/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0579 - val_loss: 0.0162
# Epoch 15/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0654 - val_loss: 0.0153
# Epoch 16/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0583 - val_loss: 0.0144
# Epoch 17/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0567 - val_loss: 0.0138
# Epoch 18/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0470 - val_loss: 0.0139
# Epoch 19/1000
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0460 - val_loss: 0.0139
# Epoch 20/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0479 - val_loss: 0.0136
# Epoch 21/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0426 - val_loss: 0.0135
# Epoch 22/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0452 - val_loss: 0.0131
# Epoch 23/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0476 - val_loss: 0.0131
# Epoch 24/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0495 - val_loss: 0.0135
# Epoch 25/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0415 - val_loss: 0.0138
# Epoch 26/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0470 - val_loss: 0.0136
# Epoch 27/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0391 - val_loss: 0.0134
# Epoch 28/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0363 - val_loss: 0.0133
# Epoch 29/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0401 - val_loss: 0.0132
# Epoch 30/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0398 - val_loss: 0.0131
# Epoch 31/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0425 - val_loss: 0.0130
# Epoch 32/1000
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0377 - val_loss: 0.0133
# Epoch 33/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0365 - val_loss: 0.0134
# Epoch 34/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0423 - val_loss: 0.0133
# Epoch 35/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0300 - val_loss: 0.0128
# Epoch 36/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0325 - val_loss: 0.0121
# Epoch 37/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0416 - val_loss: 0.0119
# Epoch 38/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0391 - val_loss: 0.0118
# Epoch 39/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0381 - val_loss: 0.0116
# Epoch 40/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0346 - val_loss: 0.0114
# Epoch 41/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0340 - val_loss: 0.0116
# Epoch 42/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0323 - val_loss: 0.0121
# Epoch 43/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0327 - val_loss: 0.0122
# Epoch 44/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0292 - val_loss: 0.0122
# Epoch 45/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0350 - val_loss: 0.0120
# Epoch 46/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0355 - val_loss: 0.0118
# Epoch 47/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0324 - val_loss: 0.0114
# Epoch 48/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0295 - val_loss: 0.0111
# Epoch 49/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0298 - val_loss: 0.0112
# Epoch 50/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0304 - val_loss: 0.0113
# Epoch 51/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0293 - val_loss: 0.0115
# Epoch 52/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0299 - val_loss: 0.0114
# Epoch 53/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0251 - val_loss: 0.0114
# Epoch 54/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0255 - val_loss: 0.0116
# Epoch 55/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0276 - val_loss: 0.0119
# Epoch 56/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0304 - val_loss: 0.0123
# Epoch 57/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0277 - val_loss: 0.0125
# Epoch 58/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0253 - val_loss: 0.0124
# Epoch 59/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0300 - val_loss: 0.0119
# Epoch 60/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0289 - val_loss: 0.0115
# Epoch 61/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0239 - val_loss: 0.0112
# Epoch 62/1000
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0267 - val_loss: 0.0112
# Epoch 63/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0247 - val_loss: 0.0115
# Epoch 64/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0267 - val_loss: 0.0118
# Epoch 65/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0236 - val_loss: 0.0125
# Epoch 66/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0262 - val_loss: 0.0129
# Epoch 67/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0213 - val_loss: 0.0130
# Epoch 68/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0249 - val_loss: 0.0132
# Epoch 69/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0252 - val_loss: 0.0131
# Epoch 70/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0242 - val_loss: 0.0129
# Epoch 71/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0254 - val_loss: 0.0128
# Epoch 72/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0239 - val_loss: 0.0125
# Epoch 73/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0249 - val_loss: 0.0121
# Epoch 74/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0244 - val_loss: 0.0121
# Epoch 75/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0223 - val_loss: 0.0121
# Epoch 76/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0214 - val_loss: 0.0121
# Epoch 77/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0218 - val_loss: 0.0122
# Epoch 78/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0193 - val_loss: 0.0123
# Epoch 79/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0205 - val_loss: 0.0123
# Epoch 80/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0205 - val_loss: 0.0125
# Epoch 81/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0212 - val_loss: 0.0125
# Epoch 82/1000
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0209 - val_loss: 0.0124
# Epoch 83/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0192 - val_loss: 0.0124
# Epoch 84/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0191 - val_loss: 0.0121
# Epoch 85/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0235 - val_loss: 0.0120
# Epoch 86/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0198 - val_loss: 0.0118
# Epoch 87/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0212 - val_loss: 0.0118
# Epoch 88/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0196 - val_loss: 0.0117
# Epoch 89/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0202 - val_loss: 0.0117
# Epoch 90/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0170 - val_loss: 0.0118
# Epoch 91/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0184 - val_loss: 0.0119
# Epoch 92/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0202 - val_loss: 0.0123
# Epoch 93/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0168 - val_loss: 0.0125
# Epoch 94/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0163 - val_loss: 0.0126
# Epoch 95/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0163 - val_loss: 0.0127
# Epoch 96/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0171 - val_loss: 0.0127
# Epoch 97/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0159 - val_loss: 0.0125
# Epoch 98/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0160 - val_loss: 0.0123
# Epoch 99/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0157 - val_loss: 0.0122
# Epoch 100/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0178 - val_loss: 0.0122
# Epoch 101/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0153 - val_loss: 0.0121
# Epoch 102/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0166 - val_loss: 0.0121
# Epoch 103/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0177 - val_loss: 0.0119
# Epoch 104/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0161 - val_loss: 0.0118
# Epoch 105/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0165 - val_loss: 0.0118
# Epoch 106/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0184 - val_loss: 0.0117
# Epoch 107/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0184 - val_loss: 0.0117
# Epoch 108/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0160 - val_loss: 0.0118
# Epoch 109/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0182 - val_loss: 0.0119
# Epoch 110/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0192 - val_loss: 0.0119
# Epoch 111/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0141 - val_loss: 0.0120
# Epoch 112/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0153 - val_loss: 0.0119
# Epoch 113/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0148 - val_loss: 0.0119
# Epoch 114/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0168 - val_loss: 0.0119
# Epoch 115/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0138 - val_loss: 0.0119
# Epoch 116/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0155 - val_loss: 0.0118
# Epoch 117/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0157 - val_loss: 0.0119
# Epoch 118/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0136 - val_loss: 0.0119
# Epoch 119/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0164 - val_loss: 0.0120
# Epoch 120/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0146 - val_loss: 0.0120
# Epoch 121/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0135 - val_loss: 0.0121
# Epoch 122/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0183 - val_loss: 0.0121
# Epoch 123/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0158 - val_loss: 0.0121
# Epoch 124/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0148 - val_loss: 0.0121
# Epoch 125/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0149 - val_loss: 0.0120
# Epoch 126/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0137 - val_loss: 0.0119
# Epoch 127/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0141 - val_loss: 0.0119
# Epoch 128/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0193 - val_loss: 0.0118
# Epoch 129/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0130 - val_loss: 0.0118
# Epoch 130/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0148 - val_loss: 0.0117
# Epoch 131/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0144 - val_loss: 0.0117
# Epoch 132/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0149 - val_loss: 0.0117
# Epoch 133/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0155 - val_loss: 0.0117
# Epoch 134/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0167 - val_loss: 0.0117
# Epoch 135/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0143 - val_loss: 0.0117
# Epoch 136/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0159 - val_loss: 0.0117
# Epoch 137/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0142 - val_loss: 0.0117
# Epoch 138/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0142 - val_loss: 0.0117
# Epoch 139/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0144 - val_loss: 0.0117
# Epoch 140/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0139 - val_loss: 0.0116
# Epoch 141/1000
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0148 - val_loss: 0.0116
# Epoch 142/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0142 - val_loss: 0.0115
# Epoch 143/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0139 - val_loss: 0.0115
# Epoch 144/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0139 - val_loss: 0.0114
# Epoch 145/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0132 - val_loss: 0.0114
# Epoch 146/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0151 - val_loss: 0.0114
# Epoch 147/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0150 - val_loss: 0.0114
# Epoch 148/1000
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0139 - val_loss: 0.0114
# Epoch 00148: early stopping

# %%
def plot_loss(history):
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend()
  plt.grid(True)

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch

plot_loss(history)

# %%
test_results = basic_model.evaluate(
    test_features[train_col_name],
    test_labels, verbose=1)
# Out:
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0125

# %%
test_input_feature = np.array(test_features[train_col_name])

# %%
pred_y = basic_model.predict(test_input_feature)
plt.figure(figsize=(20,5))
actual_trend=test_labels.values
plt.plot(pred_y, color='orange', label='Prediction')
plt.plot(actual_trend, label='Actual')
plt.legend()
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name='normalization_1_input'), name='normalization_1_input', description="created by layer 'normalization_1_input'"), but it was called on an input with incompatible shape (None, 7).

# %%
test_input_feature = np.array(test_features[train_col_name])
pred_y = basic_model.predict(test_input_feature)
# plt.figure(figsize=(20,5))
actual_trend=test_labels.values
plt.scatter(pred_y,actual_trend,  color='orange')
plt.show()
